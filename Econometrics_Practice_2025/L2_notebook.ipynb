# %% [markdown]
# # 欢迎学习 Jupyter Notebook
#
# Jupyter Notebook 是一款强大的交互式计算工具，适合用于
#
# - **代码编写与运行**
# - **文档撰写**（支持 Markdown 和 LaTeX 数学公式）
# - **数据分析与可视化**
# - **教学与协作**
#
# 让我们开始学习它的功能

# %% [markdown]
# ## 标题与文本格式化
#
# 在 Jupyter Notebook 中，我们可以使用 Markdown 来创建不同层级的标题和格式化文本
#
# ### 标题示例
# - `# 一级标题`
# - `## 二级标题`
# - `### 三级标题`
#
# ### 文本格式化示例
# - **加粗文本**：`**加粗文本**`
# - *斜体文本*：`*斜体文本*`
# - ~~删除文本~~：`~~删除文本~~`

# %% [markdown]
# ## 列表与链接
# ### 无序列表
# - 第一项
# - 第二项
# - 第三项
#
# ### 有序列表
# 1. 第一项
# 2. 第二项
# 3. 第三项

# %% [markdown]
# ## 链接与图片
#
# - 链接示例：[访问我的主页](https://space.bilibili.com/523995133)
#
#
# - 图片示例：
#
#
# ![城市景观](https://img0.baidu.com/it/u=25183460,870873689&fm=253)

# %% [markdown]
# ## 代码块与内联代码
#
# ### 内联代码
# `import math` 是 Python 的数学库导入语句
#
# ### 多行代码块
# ```python
# import math
# print("Hello, Jupyter Notebook!")
# print(math.pi)

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ## 数学公式
# Jupyter Notebook 支持 LaTeX 数学公式，既可以嵌入到行内，也可以单独展示。
#
# ### 行内公式
# 使用 `$公式内容$` 表示，例如：$y = mx + b$
#
# ### 独占一行公式
# 使用 `$$公式内容$$` 表示：$$y = x^2 + 3x + 5$$
#
# ### 复杂公式示例
# $$\frac{\sqrt{x^2 + y^2}}{z}$$
# $$\sum_{i=1}^n x_i$$

# %% [markdown]
# ## 数据可视化
# Jupyter Notebook 提供了强大的可视化能力，以下是一个简单的示例:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, label='sin(x)')
plt.title('Sine Function')
plt.xlabel('x values')
plt.ylabel('y values')
plt.legend()
